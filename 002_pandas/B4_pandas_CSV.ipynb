# %%
import pandas as pd

# %%
data1=pd.read_csv("D:\\data science\\diploma\\New folder (2)\\MAD1\\data.csv")

# %%
data1
# Out:
#     Student id   Course id   Marks
# 0         1001        2001      56
# 1         1002        2001      67
# 2         1003        2001      78
# 3         1004        2001      90
# 4         1005        2001      45
# 5         1001        2002      58
# 6         1002        2002      98
# 7         1009        2002      12
# 8         1007        2002      99
# 9         1008        2002      39
# 10        1003        2003      34
# 11        1004        2003      43
# 12        1000        2003      25
# 13        1060        2003      60
# 14        1090        2003      88
# 15        1005        2004      81
# 16        1080        2004      59
# 17        1030        2004      87
# 18        1001        2004      35
# 19        1090        2004      33

# %%
data1.columns
# Out:
# Index(['Student id', ' Course id', ' Marks'], dtype='object')

# %% [markdown]
# # only to perticular row

# %% [markdown]
# # pd.read_csv("path\\filename",nrows=number of rows)

# %%
data2=pd.read_csv("D:\\data science\\diploma\\New folder (2)\\MAD1\\data.csv",nrows=3)

# %%
data2
# Out:
#    Student id   Course id   Marks
# 0        1001        2001      56
# 1        1002        2001      67
# 2        1003        2001      78

# %% [markdown]
# # only to perticular cols

# %% [markdown]
# # pd.read_csv("path\\filename",usecols=[list of index])

# %%
data3=pd.read_csv("D:\\data science\\diploma\\New folder (2)\\MAD1\\data.csv",usecols=[2])

# %%
data3
# Out:
#      Marks
# 0       56
# 1       67
# 2       78
# 3       90
# 4       45
# 5       58
# 6       98
# 7       12
# 8       99
# 9       39
# 10      34
# 11      43
# 12      25
# 13      60
# 14      88
# 15      81
# 16      59
# 17      87
# 18      35
# 19      33

# %% [markdown]
# # only to perticular cols and rows

# %%
data4=pd.read_csv("D:\\data science\\diploma\\New folder (2)\\MAD1\\data.csv",nrows=3,usecols=[0,2])

# %%
data4
# Out:
#    Student id   Marks
# 0        1001      56
# 1        1002      67
# 2        1003      78

# %% [markdown]
# # we can skip row

# %%
data5=pd.read_csv("D:\\data science\\diploma\\New folder (2)\\MAD1\\data.csv",skiprows=[1,2,6,4,8,11])

# %%
data5
# Out:
#     Student id   Course id   Marks
# 0         1003        2001      78
# 1         1005        2001      45
# 2         1002        2002      98
# 3         1007        2002      99
# 4         1008        2002      39
# 5         1004        2003      43
# 6         1000        2003      25
# 7         1060        2003      60
# 8         1090        2003      88
# 9         1005        2004      81
# 10        1080        2004      59
# 11        1030        2004      87
# 12        1001        2004      35
# 13        1090        2004      33

# %% [markdown]
# # we can make any col index

# %%
data6=pd.read_csv("D:\\data science\\diploma\\New folder (2)\\MAD1\\data.csv",index_col=2)

# %%
data6
# Out:
#         Student id   Course id
#  Marks
# 56            1001        2001
# 67            1002        2001
# 78            1003        2001
# 90            1004        2001
# 45            1005        2001
# 58            1001        2002
# 98            1002        2002
# 12            1009        2002
# 99            1007        2002
# 39            1008        2002
# 34            1003        2003
# 43            1004        2003
# 25            1000        2003
# 60            1060        2003
# 88            1090        2003
# 81            1005        2004
# 59            1080        2004
# 87            1030        2004
# 35            1001        2004
# 33            1090        2004

# %% [markdown]
# # to print first five rows
# #head() function

# %%
data1.head()
# Out:
#    Student id   Course id   Marks
# 0        1001        2001      56
# 1        1002        2001      67
# 2        1003        2001      78
# 3        1004        2001      90
# 4        1005        2001      45

# %%
data1.head(3)
# Out:
#    Student id   Course id   Marks
# 0        1001        2001      56
# 1        1002        2001      67
# 2        1003        2001      78

# %% [markdown]
# # to print last five rows
# #tail() function

# %%
data1.tail()
# Out:
#     Student id   Course id   Marks
# 15        1005        2004      81
# 16        1080        2004      59
# 17        1030        2004      87
# 18        1001        2004      35
# 19        1090        2004      33

# %%
data1.tail(2)
# Out:
#     Student id   Course id   Marks
# 18        1001        2004      35
# 19        1090        2004      33

# %% [markdown]
# # to change data type col
# #  pd.read_csv("file path",dtype={"col name": "data type"})

# %%
data7=pd.read_csv("D:\\data science\\diploma\\New folder (2)\\MAD1\\data.csv",dtype={2:"float64"})

# %%
data7
# Out:
#     Student id   Course id   Marks
# 0         1001        2001    56.0
# 1         1002        2001    67.0
# 2         1003        2001    78.0
# 3         1004        2001    90.0
# 4         1005        2001    45.0
# 5         1001        2002    58.0
# 6         1002        2002    98.0
# 7         1009        2002    12.0
# 8         1007        2002    99.0
# 9         1008        2002    39.0
# 10        1003        2003    34.0
# 11        1004        2003    43.0
# 12        1000        2003    25.0
# 13        1060        2003    60.0
# 14        1090        2003    88.0
# 15        1005        2004    81.0
# 16        1080        2004    59.0
# 17        1030        2004    87.0
# 18        1001        2004    35.0
# 19        1090        2004    33.0

# %%
data10=pd.read_csv("D:\\data science\\diploma\\New folder (2)\\MAD1\\data.csv",nrows=0)

# %%
data10
# Out:
# Empty DataFrame
# Columns: [Student id,  Course id,  Marks]
# Index: []
