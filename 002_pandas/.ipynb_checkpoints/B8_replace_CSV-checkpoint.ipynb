# %%
import pandas as pd

# %%
data = pd.read_csv("D:\\data science\\diploma\\New folder (2)\\MAD1\\data.csv")

# %%
data
# Out:
#     Student id   Course id   Marks
# 0         1001        2001      56
# 1         1002        2001      67
# 2         1003        2001      78
# 3         1004        2001      90
# 4         1005        2001      45
# 5         1001        2002      58
# 6         1002        2002      98
# 7         1009        2002      12
# 8         1007        2002      99
# 9         1008        2002      39
# 10        1003        2003      34
# 11        1004        2003      43
# 12        1000        2003      25
# 13        1060        2003      60
# 14        1090        2003      88
# 15        1005        2004      81
# 16        1080        2004      59
# 17        1030        2004      87
# 18        1001        2004      35
# 19        1090        2004      33

# %% [markdown]
# # replacing the value
# # .replace(to_replace="your want to replace",value="with which you want to replace")

# %%
data.replace(to_replace=2004,value="A")
# Out:
#     Student id  Course id   Marks
# 0         1001       2001      56
# 1         1002       2001      67
# 2         1003       2001      78
# 3         1004       2001      90
# 4         1005       2001      45
# 5         1001       2002      58
# 6         1002       2002      98
# 7         1009       2002      12
# 8         1007       2002      99
# 9         1008       2002      39
# 10        1003       2003      34
# 11        1004       2003      43
# 12        1000       2003      25
# 13        1060       2003      60
# 14        1090       2003      88
# 15        1005          A      81
# 16        1080          A      59
# 17        1030          A      87
# 18        1001          A      35
# 19        1090          A      33

# %% [markdown]
# # to_replace=single value  value=single value

# %%
data.replace(2003,"C")
# Out:
#     Student id  Course id   Marks
# 0         1001       2001      56
# 1         1002       2001      67
# 2         1003       2001      78
# 3         1004       2001      90
# 4         1005       2001      45
# 5         1001       2002      58
# 6         1002       2002      98
# 7         1009       2002      12
# 8         1007       2002      99
# 9         1008       2002      39
# 10        1003          C      34
# 11        1004          C      43
# 12        1000          C      25
# 13        1060          C      60
# 14        1090          C      88
# 15        1005       2004      81
# 16        1080       2004      59
# 17        1030       2004      87
# 18        1001       2004      35
# 19        1090       2004      33

# %%
# to_replace=list  value=single value

# %%
data.replace([2001,2002,2003,2004],"x")
# Out:
#     Student id  Course id   Marks
# 0         1001          x      56
# 1         1002          x      67
# 2         1003          x      78
# 3         1004          x      90
# 4         1005          x      45
# 5         1001          x      58
# 6         1002          x      98
# 7         1009          x      12
# 8         1007          x      99
# 9         1008          x      39
# 10        1003          x      34
# 11        1004          x      43
# 12        1000          x      25
# 13        1060          x      60
# 14        1090          x      88
# 15        1005          x      81
# 16        1080          x      59
# 17        1030          x      87
# 18        1001          x      35
# 19        1090          x      33

# %%
# to_replace=list  value=list

# %%
data.replace([2001,2002,2003,2004],[1,2,3,4])
# Out:
#     Student id   Course id   Marks
# 0         1001           1      56
# 1         1002           1      67
# 2         1003           1      78
# 3         1004           1      90
# 4         1005           1      45
# 5         1001           2      58
# 6         1002           2      98
# 7         1009           2      12
# 8         1007           2      99
# 9         1008           2      39
# 10        1003           3      34
# 11        1004           3      43
# 12        1000           3      25
# 13        1060           3      60
# 14        1090           3      88
# 15        1005           4      81
# 16        1080           4      59
# 17        1030           4      87
# 18        1001           4      35
# 19        1090           4      33

# %% [markdown]
# # to_replace=({"col name":"value in col yu want t0 replace"}  value="value with which you wnt to replace")

# %%
data.replace({"Student id":1001},"A")
# Out:
#    Student id   Course id   Marks
# 0           A        2001      56
# 1        1002        2001      67
# 2        1003        2001      78
# 3        1004        2001      90
# 4        1005        2001      45
# 5           A        2002      58
# 6        1002        2002      98
# 7        1009        2002      12
# 8        1007        2002      99
# 9        1008        2002      39
# 10       1003        2003      34
# 11       1004        2003      43
# 12       1000        2003      25
# 13       1060        2003      60
# 14       1090        2003      88
# 15       1005        2004      81
# 16       1080        2004      59
# 17       1030        2004      87
# 18          A        2004      35
# 19       1090        2004      33

# %%
data.replace({"Student id":1001,"Course id":2001},"x")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 data.replace({"Student id":1001},{"Course id":2001},"x")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:5282, in DataFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    5272 @doc(NDFrame.replace, **_shared_doc_kwargs)
#    5273 def replace(
#    5274     self,
#    (...)
#    5280     method: str | lib.NoDefault = lib.no_default,
#    5281 ):
# -> 5282     return super().replace(
#    5283         to_replace=to_replace,
#    5284         value=value,
#    5285         inplace=inplace,
#    5286         limit=limit,
#    5287         regex=regex,
#    5288         method=method,
#    5289     )
#
# ...
