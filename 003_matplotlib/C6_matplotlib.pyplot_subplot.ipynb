# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.subplot(2,2,1)
plt.subplot(2,2,2)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
plt.show()

# %%
plt.subplot(3,3,1)
plt.subplot(3,3,2)
plt.subplot(3,3,3)
plt.subplot(3,3,4)
plt.subplot(3,3,5)
plt.subplot(3,3,6)
plt.subplot(3,3,7)
plt.subplot(3,3,8)
plt.subplot(3,3,9)
plt.show()

# %% [markdown]
# # graph 1

# %%
data=pd.read_csv("D:\\data science\\diploma\\New folder (2)\\mlp\\self\\googleplaystore.csv",nrows=1000)
x=data["Rating"]
y=data["Reviews"]

# %%
plt.subplot(221)
plt.figure(figsize=(4,4))
plt.scatter(x,y,c="y",marker="*")
plt.title("google play store")
plt.xlabel("rating")
plt.ylabel("Reviws")
plt.show()


plt.subplot(2,2,2)
plt.figure(figsize=(4,4))
plt.scatter(x,y,c="y",marker="*")
plt.title("google play store")
plt.xlabel("rating")
plt.ylabel("Reviws")
plt.show()


plt.subplot(2,2,3)
plt.figure(figsize=(4,4))
plt.scatter(x,y,c="y",marker="*")
plt.title("google play store")
plt.xlabel("rating")
plt.ylabel("Reviws")

plt.subplot(2,2,4)
plt.figure(figsize=(4,4))
plt.scatter(x,y,c="y",marker="*")
plt.title("google play store")
plt.xlabel("rating")
plt.ylabel("Reviws")

plt.show()
